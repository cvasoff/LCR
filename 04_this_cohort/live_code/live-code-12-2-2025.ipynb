# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load in airbnb data
airbnb = pd.read_csv("dataset/listings.csv")
airbnb
# Out:
#                 id             neighbourhood        room_type  accommodates  \
# 0     1.318800e+04                Riley Park  Entire home/apt             4
# 1     1.335800e+04                  Downtown  Entire home/apt             2
# 2     1.349000e+04  Kensington-Cedar Cottage  Entire home/apt             2
# 3     1.426700e+04  Kensington-Cedar Cottage  Entire home/apt             4
# 4     1.625400e+04          Hastings-Sunrise  Entire home/apt             4
# ...            ...                       ...              ...           ...
# 4981  9.970000e+17                  Downtown  Entire home/apt             4
# 4982  9.970000e+17              South Cambie  Entire home/apt             4
# 4983  9.970000e+17              South Cambie     Private room             2
# 4984  9.970000e+17                  Downtown  Entire home/apt             4
# 4985  9.980000e+17         Downtown Eastside  Entire home/apt             2
#
#       bathrooms  bedrooms  beds  price
# 0           1.0       0.0   2.0     14
# 1           1.0       1.0   1.0     20
# 2           1.0       1.0   1.0     35
# 3           1.0       1.0   2.0     35
# 4           1.0       2.0   3.0     36
# ...         ...       ...   ...    ...
# 4981        1.0       1.0   2.0   3000
# 4982        NaN       2.0   NaN   5714
# 4983        1.0       1.0   0.0   8495
# 4984        NaN       2.0   NaN   9600
# 4985        1.0       1.0   0.0   9999
#
# [4986 rows x 8 columns]

# %%
airbnb["price"].mean() #population parameter
# Out:
# np.float64(249.16526273565984)

# %%
#np.random.seed(100)
airbnb.sample(n=40)["price"].mean() #point estimate
# Out:
# np.float64(237.3)

# %%
sample_list = []

for i in range(20_000):
    sample = airbnb.sample(n = 40) #randomly sample 40 listings
    sample = sample.assign(replicate = i) #keep track of sample number
    sample_list.append(sample) #append dataframe to the list

# %%
samples = pd.concat(sample_list) #concatenate all df into one large one
samples
# Out:
#                 id             neighbourhood        room_type  accommodates  \
# 3628  7.650000e+17            Mount Pleasant  Entire home/apt             2
# 3668  7.740000e+17  Kensington-Cedar Cottage  Entire home/apt            10
# 3070  6.430000e+17         Dunbar Southlands  Entire home/apt             4
# 2084  4.315034e+07                  Downtown  Entire home/apt             2
# 4425  9.130000e+17         Downtown Eastside  Entire home/apt             6
# ...            ...                       ...              ...           ...
# 2133  4.422732e+07       Victoria-Fraserview     Private room             2
# 2354  4.873766e+07          Hastings-Sunrise  Entire home/apt             2
# 2170  4.534524e+07                  Downtown  Entire home/apt             6
# 3798  8.030000e+17       Victoria-Fraserview     Private room             1
# 4968  9.940000e+17                    Sunset  Entire home/apt             6
#
#       bathrooms  bedrooms  beds  price  replicate
# 3628        NaN       1.0   NaN    275          0
# 3668        1.5       4.0   4.0    280          0
# 3070        1.0       2.0   2.0    226          0
# 2084        1.0       1.0   2.0    165          0
# 4425        2.0       3.0   4.0    412          0
# ...         ...       ...   ...    ...        ...
# 2133        NaN       NaN   NaN    168      19999
# 2354        1.0       0.0   1.0    179      19999
# 2170        2.0       2.0   3.0    169      19999
# 3798        1.0       1.0   1.0    298      19999
# 4968        2.5       3.0   4.0   1600      19999
#
# [800000 rows x 9 columns]

# %%
sample_estimates = samples.groupby("replicate")["price"].mean().reset_index(name="sample_mean")
sample_estimates
# Out:
#        replicate  sample_mean
# 0              0      242.500
# 1              1      303.525
# 2              2      216.775
# 3              3      200.300
# 4              4      269.600
# ...          ...          ...
# 19995      19995      190.725
# 19996      19996      251.575
# 19997      19997      186.150
# 19998      19998      304.750
# 19999      19999      288.050
#
# [20000 rows x 2 columns]

# %%
# Plot the histogram of the sampling distribution
plt.figure(figsize=(10, 6))
plt.hist(sample_estimates['sample_mean'], bins=30, edgecolor='black')


# Add titles and labels
plt.title('Sampling Distribution of Mean Price Listings')
plt.xlabel('Means')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
#Bootstrapping
np.random.seed(1234)
one_sample = airbnb.sample(n=40) #this is our single sample
one_sample['price'].mean()
# Out:
# np.float64(219.85)

# %%
# Histogram of price per night (dollars) for one sample of size 40.
plt.figure(figsize=(10, 6))
plt.hist(one_sample['price'], bins=30, edgecolor='black', alpha=0.7)

# Add titles and labels
plt.title('Histogram of price per night (dollars) for one sample of size 40')
plt.xlabel('Price per night')
plt.ylabel('Frequency')

# Show the plot
plt.grid(True)
plt.show()

# %%
boot1 = one_sample.sample(frac=1, replace = True) #bootstrap sample
boot1
# Out:
#                 id             neighbourhood        room_type  accommodates  \
# 3017  6.310000e+17                  West End  Entire home/apt             2
# 608   1.554257e+07                 Kitsilano  Entire home/apt             5
# 240   5.347437e+06                  Downtown  Entire home/apt             3
# 361   8.429321e+06                  Fairview  Entire home/apt             4
# 149   3.100878e+06                  Downtown  Entire home/apt             2
# 1465  3.287258e+07                 Kitsilano  Entire home/apt             4
# 3599  7.590000e+17  Kensington-Cedar Cottage  Entire home/apt             8
# 548   1.455531e+07        Grandview-Woodland  Entire home/apt             2
# 240   5.347437e+06                  Downtown  Entire home/apt             3
# 1619  3.519493e+07                  West End  Entire home/apt             3
# 2912  5.970000e+17                Riley Park  Entire home/apt             9
# 273   6.315732e+06                  Fairview  Entire home/apt             3
# 2620  5.255417e+07         Downtown Eastside  Entire home/apt             4
# 4419  9.120000e+17                  Downtown  Entire home/apt             4
# 4601  9.360000e+17         Downtown Eastside  Entire home/apt             4
# 2549  5.156516e+07        Grandview-Woodland  Entire home/apt             4
# 2480  5.073003e+07                  Oakridge  Entire home/apt             3
# 3017  6.310000e+17                  West End  Entire home/apt             2
# 1594  3.490318e+07                  West End  Entire home/apt             6
# 3560  7.510000e+17                 Kitsilano  Entire home/apt             4
# 2692  5.331242e+07                Strathcona  Entire home/apt             4
# 548   1.455531e+07        Grandview-Woodland  Entire home/apt             2
# 2692  5.331242e+07                Strathcona  Entire home/apt             4
# 2696  5.333958e+07             Arbutus Ridge  Entire home/apt             3
# 4601  9.360000e+17         Downtown Eastside  Entire home/apt             4
# 988   2.348250e+07                  Fairview  Entire home/apt             2
# 2912  5.970000e+17                Riley Park  Entire home/apt             9
# 273   6.315732e+06                  Fairview  Entire home/apt             3
# 142   2.988185e+06                  West End  Entire home/apt             4
# 240   5.347437e+06                  Downtown  Entire home/apt             3
# 3300  6.910000e+17                  Downtown  Entire home/apt             4
# 149   3.100878e+06                  Downtown  Entire home/apt             2
# 3076  6.440000e+17  Kensington-Cedar Cottage  Entire home/apt             2
# 4255  8.910000e+17         Downtown Eastside  Entire home/apt             4
# 1619  3.519493e+07                  West End  Entire home/apt             3
# 1226  2.745958e+07                  Downtown  Entire home/apt             1
# 1594  3.490318e+07                  West End  Entire home/apt             6
# 988   2.348250e+07                  Fairview  Entire home/apt             2
# 1594  3.490318e+07                  West End  Entire home/apt             6
# 310   7.183413e+06        Grandview-Woodland     Private room             2
#
#       bathrooms  bedrooms  beds  price
# 3017        1.0       1.0   0.0    223
# 608         1.0       2.0   3.0     99
# 240         1.0       2.0   2.0     69
# 361         1.0       1.0   1.0     79
# 149         1.0       1.0   0.0     60
# 1465        2.0       2.0   2.0    136
# 3599        NaN       3.0   NaN    273
# 548         NaN       1.0   NaN     95
# 240         1.0       2.0   2.0     69
# 1619        1.0       1.0   2.0    143
# 2912        3.0       4.0   5.0    214
# 273         1.0       1.0   2.0     70
# 2620        1.0       1.0   2.0    198
# 4419        1.5       2.0   2.0    409
# 4601        NaN       2.0   NaN    495
# 2549        1.0       2.0   2.0    192
# 2480        NaN       2.0   NaN    188
# 3017        1.0       1.0   0.0    223
# 1594        2.0       3.0   3.0    141
# 3560        1.0       1.0   2.0    269
# 2692        1.0       2.0   3.0    200
# 548         NaN       1.0   NaN     95
# 2692        1.0       2.0   3.0    200
# 2696        1.0       1.0   0.0    200
# 4601        NaN       2.0   NaN    495
# 988         1.0       1.0   1.0    118
# 2912        3.0       4.0   5.0    214
# 273         1.0       1.0   2.0     70
# 142         NaN       2.0   NaN     59
# 240         1.0       2.0   2.0     69
# 3300        1.0       1.0   1.0    249
# 149         1.0       1.0   0.0     60
# 3076        1.0       1.0   1.0    227
# 4255        1.0       0.0   0.0    372
# 1619        1.0       1.0   2.0    143
# 1226        NaN       1.0   NaN    126
# 1594        2.0       3.0   3.0    141
# 988         1.0       1.0   1.0    118
# 1594        2.0       3.0   3.0    141
# 310         1.0       1.0   1.0     75

# %%
# Plot the histogram of the bootstrap distribution
plt.figure(figsize=(10, 6))
plt.hist(boot1['price'], bins=20, edgecolor='black', alpha=0.7)

# Add titles and labels
plt.title('Bootstrap distribution')
plt.xlabel('Price per night ($USD)')
plt.ylabel('Frequency')

# Show the plot
plt.grid(True)
plt.show()

# %%
bootstrap_samples = []

for i in range(20_000):
    sample = one_sample.sample(frac = 1, replace = True)
    sample = sample.assign(replicate = i)
    bootstrap_samples.append(sample)

# %%
boot20000 = pd.concat(bootstrap_samples)
boot20000
# Out:
#                 id       neighbourhood        room_type  accommodates  \
# 2480  5.073003e+07            Oakridge  Entire home/apt             3
# 4419  9.120000e+17            Downtown  Entire home/apt             4
# 273   6.315732e+06            Fairview  Entire home/apt             3
# 548   1.455531e+07  Grandview-Woodland  Entire home/apt             2
# 3795  8.020000e+17          Riley Park  Entire home/apt             4
# ...            ...                 ...              ...           ...
# 3560  7.510000e+17           Kitsilano  Entire home/apt             4
# 1465  3.287258e+07           Kitsilano  Entire home/apt             4
# 3115  6.550000e+17            Downtown  Entire home/apt             5
# 2480  5.073003e+07            Oakridge  Entire home/apt             3
# 1465  3.287258e+07           Kitsilano  Entire home/apt             4
#
#       bathrooms  bedrooms  beds  price  replicate
# 2480        NaN       2.0   NaN    188          0
# 4419        1.5       2.0   2.0    409          0
# 273         1.0       1.0   2.0     70          0
# 548         NaN       1.0   NaN     95          0
# 3795        1.0       2.0   2.0    298          0
# ...         ...       ...   ...    ...        ...
# 3560        1.0       1.0   2.0    269      19999
# 1465        2.0       2.0   2.0    136      19999
# 3115        2.0       3.0   3.0    230      19999
# 2480        NaN       2.0   NaN    188      19999
# 1465        2.0       2.0   2.0    136      19999
#
# [800000 rows x 9 columns]

# %%
boot_means = boot20000.groupby("replicate")["price"].mean().reset_index(name = "mean_price")
boot_means
# Out:
#        replicate  mean_price
# 0              0     208.250
# 1              1     205.800
# 2              2     183.925
# 3              3     211.600
# 4              4     239.475
# ...          ...         ...
# 19995      19995     176.725
# 19996      19996     217.450
# 19997      19997     204.600
# 19998      19998     216.900
# 19999      19999     198.375
#
# [20000 rows x 2 columns]

# %%
# Plot the histogram of the sampling distribution
plt.figure(figsize=(10, 6))
plt.hist(boot_means['mean_price'], bins=30, edgecolor='black')


# Add titles and labels
plt.title('Distribution of the bootstrap sample mean')
plt.xlabel('Means')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
boot_means["mean_price"].quantile([0.025,0.975])
# Out:
# 0.025    171.248750
# 0.975    276.300625
# Name: mean_price, dtype: float64
